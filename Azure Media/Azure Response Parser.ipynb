# %%
import ijson
import json
import numpy as np
import pandas as pd
import os
from pandas.io.json import json_normalize

# %%
google_json_path='./inputs/Google/FRIENDS - Hulu (Japan)_celebrity.json'
aws_json_path = './inputs/aws_FRIENDS.json'
azure_json_path = './inputs/azure_FRIENDS.json'

# %%
def convert_to_secs(time_str):
    h, m, s = time_str.split(':')
    return int(h)*3600 + int(m)*60 + float(s)

# %%
class AzureResponseParser:
    def __init__(self, azure_json_path):
        self.azure_json_path = azure_json_path

    def get_celebrity_info(self):
        with open(self.azure_json_path, 'r') as f:
            celebrities_list = list(ijson.items(f, 'videos.item.insights.faces.item'))
        df = json_normalize(celebrities_list)
        df['source'] = 'microsoft'
        segment_df = df.drop(['description', 'thumbnailId', 'referenceId', 'referenceType', 'title', 'thumbnails'], axis=1)
        segment_df = segment_df.explode('instances').reset_index(drop=True)
        segment_df['segment.start_time'] = segment_df['instances'].apply(lambda x: convert_to_secs(x['start']) if pd.notna(x) else x)
        segment_df['segment.end_time'] = segment_df['instances'].apply(lambda x: convert_to_secs(x['end']) if pd.notna(x) else x)
        segment_df = segment_df.rename(columns = {"imageUrl":"url"}).drop('instances', axis=1)
        return segment_df

    def get_logo_info(self):
        pass
    
    def get_label_info(self):
        with open(self.azure_json_path, 'r') as f:
            labels_list = list(ijson.items(f, 'videos.item.insights.labels.item'))
        df = json_normalize(labels_list)
        df['source'] = 'microsoft'
        df = df.explode('instances').reset_index(drop=True)
        df = df.join(json_normalize(df['instances']))
        df['segment.start_time'] = df['start'].apply(lambda x: convert_to_secs(x) if pd.notna(x) else x)
        df['segment.end_time'] = df['end'].apply(lambda x: convert_to_secs(x) if pd.notna(x) else x)
        df.drop(['instances', 'adjustedStart', 'adjustedEnd', 'start', 'end'], axis=1, inplace=True)
        return df
        
    def __add_bounding_box(self, row):
        temp_dict = { 'left': row['left'], \
                      'right': row['left'] + row['width'], \
                      'top' : row['top'], \
                      'bottom' : row['top'] + row['height'] }
        return temp_dict
    
    def get_text_info(self):
        with open(self.azure_json_path, 'r') as f:
            ocr_list = list(ijson.items(f, 'videos.item.insights.ocr.item'))
        df = json_normalize(ocr_list)
        df['source'] = 'microsoft'
        df = df.explode('instances').reset_index(drop=True)
        df['segment.start_time'] = df['instances'].apply(lambda x: convert_to_secs(x['start']) if pd.notna(x) else x)
        df['segment.end_time'] = df['instances'].apply(lambda x: convert_to_secs(x['end']) if pd.notna(x) else x)
        df['bounding_box'] = df.apply(self.__add_bounding_box, axis=1)
        df.drop(['instances', 'left', 'top', 'width', 'height'], axis=1, inplace=True)
        return df

    def get_speech_info(self):
        with open(self.azure_json_path, 'r') as f:
            transcript_list = list(ijson.items(f, 'videos.item.insights.transcript.item'))
        df = json_normalize(transcript_list)
        df['source'] = 'microsoft'
        df = df.explode('instances').reset_index(drop=True)
        df['segment.start_time'] = df['instances'].apply(lambda x: convert_to_secs(x['start']) if pd.notna(x) else x)
        df['segment.end_time'] = df['instances'].apply(lambda x: convert_to_secs(x['end']) if pd.notna(x) else x)
        df.drop(['instances', 'speakerId'], axis=1, inplace=True)
        return df
        
    def __handle_keyframes(self, input_list):
        out_list = []
        for keyframe in input_list:
            instances = keyframe.pop('instances', None)
            if instances:
                keyframe['start_time'] = convert_to_secs(instances[0]['start'])
                keyframe['end_time'] = convert_to_secs(instances[0]['end'])
        return input_list
    
    def get_shots_info(self):
        with open(self.azure_json_path, 'r') as f:
            shot_list = list(ijson.items(f, 'videos.item.insights.shots.item'))
        df = json_normalize(shot_list)
        df['source'] = 'microsoft'
        df = df.explode('instances').reset_index(drop=True)
        df['segment.start_time'] = df['instances'].apply(lambda x: convert_to_secs(x['start']) if pd.notna(x) else x)
        df['segment.end_time'] = df['instances'].apply(lambda x: convert_to_secs(x['end']) if pd.notna(x) else x)
        df['keyframes'] = df['keyFrames'].apply(self.__handle_keyframes)
        df.drop(['instances', 'keyFrames'], axis=1, inplace=True)
        return df
    
    def get_content_moderation_info(self):
        with open(self.azure_json_path, 'r') as f:
            moderation_list = list(ijson.items(f, 'videos.item.insights.visualContentModeration.item'))
        df = json_normalize(moderation_list)
        df['source'] = 'microsoft'
        df = df.explode('instances').reset_index(drop=True)
        df['segment.start_time'] = df['instances'].apply(lambda x: convert_to_secs(x['start']) if pd.notna(x) else x)
        df['segment.end_time'] = df['instances'].apply(lambda x: convert_to_secs(x['end']) if pd.notna(x) else x)
        df.drop('instances', axis=1, inplace=True)
        return df

# %%
azureParser = AzureResponseParser(azure_json_path)
azure_celeb_info = azureParser.get_celebrity_info()
azure_celeb_info
# Out:
#       id              name confidence  \
# 0   1279   David Schwimmer          1
# 1   1279   David Schwimmer          1
# 2   1279   David Schwimmer          1
# 3   1007     Courteney Cox     0.9986
# 4   1007     Courteney Cox     0.9986
# 5   1007     Courteney Cox     0.9986
# 6   1225      Matt LeBlanc          1
# 7   1225      Matt LeBlanc          1
# 8   1225      Matt LeBlanc          1
# 9   1225      Matt LeBlanc          1
# 10  1011       Lisa Kudrow     0.9929
# 11  1011       Lisa Kudrow     0.9929
# 12  1001  Jennifer Aniston     0.9677
# 13  1001  Jennifer Aniston     0.9677
# 14  1001  Jennifer Aniston     0.9677
# 15  1253     Matthew Perry     0.8623
# 16  1103        Unknown #1          0
# 17  1103        Unknown #1          0
# 18  1103        Unknown #1          0
# 19  1103        Unknown #1          0
# 20  1103        Unknown #1          0
# 21  1177        Unknown #2          0
# 22  1177        Unknown #2          0
# 23  1304        Unknown #3          0
# 24  1084        Unknown #4          0
# 25  1184        Unknown #5          0
# 26  1008        Unknown #6          0
# 27  1220        Unknown #8          0
# 28  1180       Unknown #10          0
# 29  1160        Unknown #9          0
# 30  1105       Unknown #11          0
# 31  1167       Unknown #12          0
# 32  1170       Unknown #13          0
# 33  1081       Unknown #14          0
# 34  1413       Unknown #15          0
#
#                                                   url     source  \
# 0   https://www.bing.com/th?id=AMMS_2400447960bb27...  microsoft
# 1   https://www.bing.com/th?id=AMMS_2400447960bb27...  microsoft
# 2   https://www.bing.com/th?id=AMMS_2400447960bb27...  microsoft
# 3   https://www.bing.com/th?id=AMMS_bc02ff04fe1dee...  microsoft
# 4   https://www.bing.com/th?id=AMMS_bc02ff04fe1dee...  microsoft
# 5   https://www.bing.com/th?id=AMMS_bc02ff04fe1dee...  microsoft
# 6   https://www.bing.com/th?id=AMMS_b4adeefb0ac306...  microsoft
# 7   https://www.bing.com/th?id=AMMS_b4adeefb0ac306...  microsoft
# 8   https://www.bing.com/th?id=AMMS_b4adeefb0ac306...  microsoft
# 9   https://www.bing.com/th?id=AMMS_b4adeefb0ac306...  microsoft
# 10  https://www.bing.com/th?id=AMMS_9d45e5a299dec4...  microsoft
# 11  https://www.bing.com/th?id=AMMS_9d45e5a299dec4...  microsoft
# 12  https://www.bing.com/th?id=AMMS_49e8b448e95989...  microsoft
# 13  https://www.bing.com/th?id=AMMS_49e8b448e95989...  microsoft
# 14  https://www.bing.com/th?id=AMMS_49e8b448e95989...  microsoft
# 15  https://www.bing.com/th?id=AMMS_623f84b3be9131...  microsoft
# 16                                               None  microsoft
# 17                                               None  microsoft
# 18                                               None  microsoft
# 19                                               None  microsoft
# 20                                               None  microsoft
# 21                                               None  microsoft
# 22                                               None  microsoft
# 23                                               None  microsoft
# 24                                               None  microsoft
# 25                                               None  microsoft
# 26                                               None  microsoft
# 27                                               None  microsoft
# 28                                               None  microsoft
# 29                                               None  microsoft
# 30                                               None  microsoft
# 31                                               None  microsoft
# 32                                               None  microsoft
# 33                                               None  microsoft
# 34                                               None  microsoft
#
#     segment.start_time  segment.end_time
# 0                9.259            10.177
# 1               18.018            20.896
# 2               23.023            23.983
# 3                0.000             1.252
# 4                3.337             3.671
# 5               18.018            20.896
# 6                0.000             1.252
# 7               11.595            12.471
# 8               13.764            14.932
# 9               26.777            27.528
# 10               0.000             1.252
# 11               3.670             5.422
# 12               0.000             1.252
# 13               3.337             3.671
# 14              26.777            27.528
# 15              14.932            15.933
# 16               1.251             2.461
# 17               4.004             5.422
# 18              15.933            18.018
# 19              20.771            20.896
# 20              26.109            27.528
# 21               9.343            10.177
# 22              15.933            18.018
# 23              15.933            18.018
# 24               3.670             5.422
# 25              10.177            11.595
# 26               0.000             1.252
# 27              11.595            12.471
# 28               9.426            10.177
# 29               5.923             6.674
# 30               2.669             3.295
# 31               6.173             6.465
# 32               7.424             7.675
# 33               1.502             1.669
# 34              25.943            26.068

# %%
azure_label_info = azureParser.get_label_info()
azure_label_info
# Out:
#     id      name             referenceId language     source confidence  \
# 0    1    People                  person    en-US  microsoft     0.9965
# 1    1    People                  person    en-US  microsoft      0.998
# 2    2    Indoor                     NaN    en-US  microsoft     0.9422
# 3    2    Indoor                     NaN    en-US  microsoft     0.9323
# 4    2    Indoor                     NaN    en-US  microsoft      0.963
# 5    3   Outdoor                     NaN    en-US  microsoft     0.9243
# 6    3   Outdoor                     NaN    en-US  microsoft     0.9881
# 7    4      Wall          structure/wall    en-US  microsoft       0.99
# 8    4      Wall          structure/wall    en-US  microsoft     0.9566
# 9    5  Standing                     NaN    en-US  microsoft       0.89
# 10   5  Standing                     NaN    en-US  microsoft       0.87
# 11   6       Man              person/man    en-US  microsoft     0.9717
# 12   7   Kitchen  structure/room/kitchen    en-US  microsoft     0.8787
# 13   8   Sitting          action/sitting    en-US  microsoft     0.9916
# 14   9    People                     NaN    en-US  microsoft     0.8831
# 15  10   Ceiling         surface/ceiling    en-US  microsoft     0.8009
# 16  11     Floor           surface/floor    en-US  microsoft     0.9784
# 17  12      Life                     NaN    en-US  microsoft      0.924
# 18  13      Room          structure/room    en-US  microsoft     0.8926
#
#     segment.start_time  segment.end_time
# 0                1.335            13.347
# 1               14.681            28.028
# 2                1.335             6.674
# 3                8.008             9.343
# 4               10.677            28.028
# 5                6.673             8.008
# 6                9.343            10.678
# 7               10.677            12.012
# 8               24.024            25.359
# 9               10.677            13.347
# 10              16.016            17.351
# 11              12.012            13.347
# 12              12.012            13.347
# 13              18.685            20.020
# 14              18.685            20.020
# 15              24.024            25.359
# 16              24.024            26.694
# 17              24.024            25.359
# 18              24.024            25.359

# %%
azure_text_info = azureParser.get_text_info()
azure_text_info
# Out:
#     id                               text confidence language     source  \
# 0    1                          "Friends"     0.9174    en-US  microsoft
# 1    1                          "Friends"     0.9174    en-US  microsoft
# 2    1                          "Friends"     0.9174    en-US  microsoft
# 3    1                          "Friends"     0.9174    en-US  microsoft
# 4    1                          "Friends"     0.9174    en-US  microsoft
# 5    2        Now being distributed on Hu     0.9324    en-US  microsoft
# 6    2        Now being distributed on Hu     0.9324    en-US  microsoft
# 7    2        Now being distributed on Hu     0.9324    en-US  microsoft
# 8    3        & CWYo" "Day" 0 Ente "n nc-     0.5238    en-US  microsoft
# 9    4   & eWyo "Sun ro Ente Le i I i nc-     0.4822    en-US  microsoft
# 10   5  & C'W'n "Day"os.Sun 0" Thing 1 Nc     0.4651    en-US  microsoft
# 11   6           & CW'0 "Day" os.Day 0" 1     0.4397    en-US  microsoft
# 12   7         & CW "Day 0 0" Thing n Inc     0.4702    en-US  microsoft
# 13   8   & W "n" "0 days 0" thing n i nc.     0.4714    en-US  microsoft
# 14   9  & CW "Day" os. Ente "Thingn n nc.     0.4848    en-US  microsoft
# 15  10                              I nc.     0.5448    en-US  microsoft
# 16  10                              I nc.     0.5448    en-US  microsoft
# 17  11                      Period Ka Red       0.78    en-US  microsoft
# 18  12                      One with love     0.8955    en-US  microsoft
# 19  12                      One with love     0.8955    en-US  microsoft
#
#     segment.start_time  segment.end_time  \
# 0               11.929            16.058
# 1               16.517            16.976
# 2               17.434            17.893
# 3               18.352            19.269
# 4               21.104            22.940
# 5               11.929            16.058
# 6               18.352            19.269
# 7               21.104            22.940
# 8               13.764            14.223
# 9               14.223            15.140
# 10              15.140            15.599
# 11              15.599            16.058
# 12              18.352            18.811
# 13              18.810            19.269
# 14              21.104            22.481
# 15              16.517            16.976
# 16              17.434            17.893
# 17              11.929            12.846
# 18              21.104            22.022
# 19              22.481            22.940
#
#                                          bounding_box
# 0   {'left': 50, 'right': 130, 'top': 28, 'bottom'...
# 1   {'left': 50, 'right': 130, 'top': 28, 'bottom'...
# 2   {'left': 50, 'right': 130, 'top': 28, 'bottom'...
# 3   {'left': 50, 'right': 130, 'top': 28, 'bottom'...
# 4   {'left': 50, 'right': 130, 'top': 28, 'bottom'...
# 5   {'left': 51, 'right': 170, 'top': 50, 'bottom'...
# 6   {'left': 51, 'right': 170, 'top': 50, 'bottom'...
# 7   {'left': 51, 'right': 170, 'top': 50, 'bottom'...
# 8   {'left': 62, 'right': 256, 'top': 74, 'bottom'...
# 9   {'left': 62, 'right': 256, 'top': 74, 'bottom'...
# 10  {'left': 62, 'right': 253, 'top': 74, 'bottom'...
# 11  {'left': 62, 'right': 216, 'top': 74, 'bottom'...
# 12  {'left': 62, 'right': 253, 'top': 74, 'bottom'...
# 13  {'left': 62, 'right': 256, 'top': 74, 'bottom'...
# 14  {'left': 62, 'right': 253, 'top': 74, 'bottom'...
# 15  {'left': 230, 'right': 256, 'top': 74, 'bottom...
# 16  {'left': 230, 'right': 256, 'top': 74, 'bottom...
# 17  {'left': 219, 'right': 411, 'top': 231, 'botto...
# 18  {'left': 306, 'right': 655, 'top': 242, 'botto...
# 19  {'left': 306, 'right': 655, 'top': 242, 'botto...

# %%
azure_speech_info = azureParser.get_speech_info()
azure_speech_info
# Out:
#    id                          text  confidence language     source  \
# 0   1                        Right.           1    en-US  microsoft
# 1   2  SNS This is Tsukuba Iceland.           1    en-US  microsoft
#
#    segment.start_time  segment.end_time
# 0                0.57             4.629
# 1                5.38            30.030

# %%
azure_shots_info = azureParser.get_shots_info()
azure_shots_info
# Out:
#     id                                tags     source  segment.start_time  \
# 0    1                      [Wide, Indoor]  microsoft               0.000
# 1    2  [Wide, CenterFace, Indoor, Medium]  microsoft               2.753
# 2    3                    [Indoor, Medium]  microsoft               5.714
# 3    4        [Medium, RightFace, Outdoor]  microsoft               6.840
# 4    5                            [Indoor]  microsoft               8.926
# 5    6       [Medium, CenterFace, Outdoor]  microsoft              10.219
# 6    7                      [Wide, Indoor]  microsoft              11.887
# 7    8        [Indoor, Medium, CenterFace]  microsoft              13.639
# 8    9  [Medium, CenterFace, Indoor, Wide]  microsoft              14.932
# 9   10                    [Medium, Indoor]  microsoft              18.060
# 10  11                            [Indoor]  microsoft              20.938
# 11  12            [Wide, LeftFace, Indoor]  microsoft              23.273
# 12  13                            [Indoor]  microsoft              24.358
# 13  14  [Medium, CenterFace, Indoor, Wide]  microsoft              26.360
# 14  15                            [Indoor]  microsoft              27.819
#
#     segment.end_time                                          keyframes
# 0              2.753  [{'id': 1, 'start_time': 0.25, 'end_time': 0.2...
# 1              5.714  [{'id': 3, 'start_time': 2.753, 'end_time': 2....
# 2              6.840  [{'id': 5, 'start_time': 5.714, 'end_time': 5....
# 3              8.926  [{'id': 7, 'start_time': 6.84, 'end_time': 6.8...
# 4             10.219  [{'id': 9, 'start_time': 8.926, 'end_time': 8....
# 5             11.887  [{'id': 10, 'start_time': 10.219, 'end_time': ...
# 6             13.639  [{'id': 11, 'start_time': 11.887, 'end_time': ...
# 7             14.932  [{'id': 13, 'start_time': 13.639, 'end_time': ...
# 8             18.060  [{'id': 15, 'start_time': 14.932, 'end_time': ...
# 9             20.938  [{'id': 17, 'start_time': 18.06, 'end_time': 1...
# 10            23.273  [{'id': 18, 'start_time': 20.938, 'end_time': ...
# 11            24.358  [{'id': 19, 'start_time': 23.273, 'end_time': ...
# 12            26.360  [{'id': 20, 'start_time': 24.358, 'end_time': ...
# 13            27.819  [{'id': 22, 'start_time': 26.36, 'end_time': 2...
# 14            28.279  [{'id': 24, 'start_time': 27.819, 'end_time': ...

# %%
azure_moderation_info = azureParser.get_content_moderation_info()
azure_moderation_info
# Out:
#    id adultScore racyScore     source  segment.start_time  segment.end_time
# 0   1     0.0024    0.9296  microsoft              13.931            13.973

# %%
restructured_json = {'celebrities': json.loads(azure_celeb_info.to_json(orient='records')),
                     'labels': json.loads(azure_label_info.to_json(orient='records')),
                     'texts': json.loads(azure_text_info.to_json(orient='records')),
                     'speech': json.loads(azure_speech_info.to_json(orient='records')),
                     'shots': json.loads(azure_shots_info.to_json(orient='records')),
                     'content_moderation': json.loads(azure_moderation_info.to_json(orient='records'))
                    }
with open('restructured_azure.json', "w") as write_file:
    json.dump(restructured_json, write_file, indent=4)
